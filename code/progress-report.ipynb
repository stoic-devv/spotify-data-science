# %% [markdown]
# # Progress report

# %% [markdown]
# ## About Data
# We have collected our data from multiple sources: Spotify and RateYourMusic. <br/>
# Spotify data consists of its metadata like name, genre, popularity and audio features like liveness, tempo, danceability, etc. <br/>
# RateYourMusic is a public forum where users review albums and songs. Its data consists of critic rating, user rating, reviews, and number of reviews.<br/>
# Link to our [dataset](https://github.com/stoic-devv/spotify-data-science/tree/main/data)

# %%
import pandas as pd
df = pd.read_csv('../data/merge-data-1.csv', sep='~')
columns = ['id', 'name', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness','valence', 'tempo', 'type', 'uri', 'duration_ms', 'time_signature', 'album', 'date', 'genres', 'track_href', 'analysis_url', 'rym rating', 'ratings', 'reviews', 'popularity']
df = df[columns]
df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  14363.000000  14363.000000  14363.000000  14363.000000  14363.000000
# mean       0.441265      0.490766      5.232055    -13.140224      0.653206
# std        0.183334      0.303645      3.518423      6.991007      0.475966
# min        0.000000      0.000000      0.000000    -60.000000      0.000000
# 25%        0.302000      0.217000      2.000000    -17.153000      0.000000
# 50%        0.435000      0.484000      5.000000    -11.518000      1.000000
# 75%        0.573000      0.762000      8.000000     -7.987500      1.000000
# max        0.967000      1.000000     11.000000      3.744000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  14363.000000  14363.000000      14363.000000  14363.000000
# mean       0.084234      0.468226          0.285407      0.205916
# std        0.130424      0.388169          0.368540      0.181797
# ...

# %%
df.iloc[[4950,4953,2980,2984]]
# Out:
#                           id                          name  danceability  \
# 4950  3TO7bbrUKrOSPGRTB5MeCz                          Time         0.359
# 4953  1TKTiKp3zbNgrBH2IwSwIx                   Us and Them         0.357
# 2980  6g8Z3jy8Glvl0EfugPH58o  While My Guitar Gently Weeps         0.576
# 2984  1uTJ14NsfGsg7ZG5tcpdGC                     Blackbird         0.647
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 4950   0.480    9   -11.790     1       0.0841         0.521
# 4953   0.302    2   -14.526     1       0.0303         0.862
# 2980   0.382    7   -10.925     1       0.0312         0.948
# 2984   0.680    9    -8.260     1       0.0611         0.346
#
#       instrumentalness  ...  time_signature                      album  \
# 4950          0.004300  ...               4  The Dark Side of the Moon
# 4953          0.559000  ...               4  The Dark Side of the Moon
# 2980          0.001500  ...               4  The Beatles [White Album]
# ...

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Challenges

# %% [markdown]
# ## Next Steps

# %% [markdown]
# ## Duties
